# %%
import os
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,10)

# %%
db=pd.read_csv('titanic_train.csv')

# %%
os.mkdir('C:/Users/AYUSH/Desktop/DWM_mini_project/new3')

# %%
os.chdir('C:/Users/AYUSH/Desktop/DWM_mini_project/new3')

# %%
top5=db.head()

# %%
top5.to_csv('top_five')

# %%
describe=db.describe()

# %%
describe.to_csv('info')

# %%
columns=db.columns

# %%
columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
hist=db.hist()
plt.savefig('histogram')

# %%
pairplot=sns.pairplot(db)
plt.savefig('pairplots')

# %%
area=db.plot.area()
plt.savefig('area')

# %%
bar=db.plot.bar()
plt.savefig('bar')

# %%
hist2=db.plot.hist()
plt.savefig('histogram2')

# %%
line=db.plot.line()
plt.savefig('line')

# %%
box=db.plot.box()
plt.savefig('box')
